# %%
import pandas as pd

# %%
databp = pd.read_excel("bp-stats-review-2019-all-data.xlsx", header=2, sheet_name=1)

# %%
databp.shape
# Out:
# (118, 60)

# %%
databp.rename(columns={'Million tonnes oil equivalent':'country'}, inplace=True)

# %%
databp = databp.drop(0, axis=0)
databp.drop(databp.index[databp.index[databp['country'] == 'Total World'][0]-1:])
# Out:
#                  country         1965         1966         1967         1968  \
# 1                 Canada   115.910849   122.991657   129.026541   137.695457
# 2                 Mexico    24.972964    26.432788    26.922222    29.291127
# 3                     US  1249.642424  1320.037950  1365.733676  1448.932114
# 4    Total North America  1390.526237  1469.462395  1521.682440  1615.918698
# 5                    NaN          NaN          NaN          NaN          NaN
# ..                   ...          ...          ...          ...          ...
# 102             Thailand     2.674457     3.163960     3.629875     4.597510
# 103              Vietnam     2.523158     4.415730     6.087783     6.312114
# 104   Other Asia Pacific    16.307446    17.315215    18.832946    20.273196
# 105   Total Asia Pacific   441.550955   482.885313   506.079866   544.087709
# 106                  NaN          NaN          NaN          NaN          NaN
#
# ...

# %%
databp.dropna()
# Out:
# Empty DataFrame
# Columns: [country, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2018.1, 2007-17, 2018.2, Unnamed: 58, Unnamed: 59]
# Index: []
#
# [0 rows x 60 columns]

# %%
databp_melt = pd.melt(frame=databp, id_vars='country')

# %%
# Out:
#                                 country variable        value
# 0                                Canada     1965   115.910849
# 1                                Mexico     1965    24.972964
# 2                                    US     1965  1249.642424
# 3                   Total North America     1965  1390.526237
# 5                             Argentina     1965    26.914442
# ...                                 ...      ...          ...
# 6656                 Total Asia Pacific   2018.2     0.431727
# 6658                        Total World   2018.2     1.000000
# 6659                     of which: OECD   2018.2     0.408877
# 6660                           Non-OECD   2018.2     0.591123
# 6661                   European Union #   2018.2     0.121762
#
# [5533 rows x 3 columns]
